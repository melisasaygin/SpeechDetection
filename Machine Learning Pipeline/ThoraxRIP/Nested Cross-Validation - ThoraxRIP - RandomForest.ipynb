# %%
#importing the needed libraries
from sklearn.datasets import load_iris
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV, cross_validate, KFold
import numpy as np
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.model_selection import KFold
from sklearn.metrics import roc_auc_score
import numpy as np
from sklearn.model_selection import LeaveOneGroupOut
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_validate
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import f1_score
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import roc_auc_score, make_scorer, recall_score, f1_score, confusion_matrix, accuracy_score

# %%
#reading in the data we will use in the machine learning pipeline, with the top ten features of the method
df = pd.read_excel('hexoskin_thorax_training_set_10_final.xlsx')
df
# Out:
#       exp_diff_mean  exp_dur_sd  duty_cycle_mean    RRV_RMSSD  ie_ratio_mean  \
# 0          0.127790    0.156604         0.492097   376.386712       0.971761
# 1          0.201451    0.152211         0.486992   351.137516       0.950939
# 2          0.199219    0.213642         0.476697   457.608476       0.913378
# 3          0.285156    0.213173         0.477750   439.827676       0.918119
# 4          0.159375    0.213828         0.481671   457.645154       0.936229
# ...             ...         ...              ...          ...            ...
# 2899       0.203125    0.200555         0.490259   334.175635       0.967894
# 2900       0.921387    0.725393         0.401725  1209.145284       0.933997
# 2901       0.106337    0.117894         0.496388   185.358320       0.987026
# 2902       2.145182    1.447558         0.412197  3053.223554       0.748645
# 2903       0.123535    0.150457         0.480523   159.999651       0.926293
#
#       insp_flow_sd   insp_amp_sd    exp_amp_sd  ie_ratio_sd  exp_dur_mean  \
# 0     1.445912e+06  5.297158e+06  5.304442e+06     0.074256      1.683594
# 1     1.034691e+06  2.361021e+06  2.676608e+06     0.057593      1.749512
# 2     1.890795e+06  3.910462e+06  3.564286e+06     0.067618      2.283203
# 3     1.316481e+06  2.710758e+06  2.535948e+06     0.082441      1.953683
# 4     9.634884e+05  3.059318e+06  3.092634e+06     0.115349      2.149088
# ...            ...           ...           ...          ...           ...
# 2899  2.209139e+06  5.263487e+06  7.984288e+06     0.108475      1.498828
# 2900  1.280213e+07  2.472549e+07  1.682432e+07     0.893126      1.939236
# 2901  2.990174e+06  5.322750e+06  5.857152e+06     0.051696      1.456641
# 2902  1.441962e+07  1.907822e+07  1.914789e+07     0.283130      2.785156
# 2903  2.040140e+06  3.928530e+06  8.147255e+06     0.049994      1.671875
#
#      Task_Label  Participant  Classification
# 0         12.0a        10785               0
# 1         12.0b        10785               0
# 2         12.0c        10785               0
# 3         12.0d        10785               0
# 4         12.0e        10785               0
# ...         ...          ...             ...
# 2899         85        98586               0
# 2900         87        98586               1
# 2901         89        98586               0
# 2902         91        98586               1
# 2903         93        98586               0
#
# [2904 rows x 13 columns]

# %%
# extracting the features from the DataFrame
features = df.drop(columns=['Classification', 'Participant', 'Task_Label'])

# extracting the Classification (0/1) and participants from the dataframe
target = df['Classification'].values
participants = df['Participant'].values
task = df['Task_Label'].values

# extracting the feature names
feature_names = features.columns.tolist()

# converting the features, target, participants to numpy arrays
features_array = features.values
target_array = target

# creating the dictionary with the needed format to enter into the nested cross-validation
data_dict = {
    'data': features_array,
    'target': target_array,
    'feature_names': feature_names,
    'participants': participants,
    'task': task
}

data_dict
# Out:
# {'data': array([[1.27790200e-01, 1.56603600e-01, 4.92097400e-01, ...,
#          5.30444166e+06, 7.42560000e-02, 1.68359380e+00],
#         [2.01450900e-01, 1.52211400e-01, 4.86992000e-01, ...,
#          2.67660774e+06, 5.75926000e-02, 1.74951170e+00],
#         [1.99218800e-01, 2.13641900e-01, 4.76696800e-01, ...,
#          3.56428630e+06, 6.76182000e-02, 2.28320310e+00],
#         ...,
#         [1.06336800e-01, 1.17894400e-01, 4.96388400e-01, ...,
#          5.85715185e+06, 5.16958000e-02, 1.45664060e+00],
#         [2.14518230e+00, 1.44755800e+00, 4.12197100e-01, ...,
#          1.91478947e+07, 2.83129900e-01, 2.78515620e+00],
#         [1.23535200e-01, 1.50456800e-01, 4.80522600e-01, ...,
#          8.14725521e+06, 4.99940000e-02, 1.67187500e+00]]),
#  'target': array([0, 0, 0, ..., 0, 1, 0]),
#  'feature_names': ['exp_diff_mean',
#   'exp_dur_sd',
#   'duty_cycle_mean',
#   'RRV_RMSSD',
#   'ie_ratio_mean',
#   'insp_flow_sd',
#   'insp_amp_sd',
#   'exp_amp_sd',
#   'ie_ratio_sd',
#   'exp_dur_mean'],
#  'participants': array([10785, 10785, 10785, ..., 98586, 98586, 98586]),
#  'task': array(['12.0a', '12.0b', '12.0c', ..., 89, 91, 93], dtype=object)}

# %%
#running the nested cross-validation for the Accelerometer method using Random Forest
from sklearn.metrics import accuracy_score, precision_score, recall_score
import xgboost as xgb

# random seed for reproducibility
random_seed = 1
np.random.seed(random_seed)

X = data_dict['data']
Y = data_dict['target']
groups = data_dict['participants']

# setting up the parameter grid: the combinations of these will be tried out for ever outer loop's inner loop
param_grid = {
    'n_estimators': [25, 50, 100, 150],
    'max_features': ['sqrt', 'log2', None],
    'max_depth': [3, 6, 9],
    'max_leaf_nodes': [3, 6, 9],
}

rfc = RandomForestClassifier(random_state=random_seed, class_weight="balanced")

logo = LeaveOneGroupOut()


# defining the techniques to use for the inner and outer loops
inner_cv = KFold(n_splits=5, shuffle=True, random_state=1)
outer_cv = logo.split(X, Y, groups)

scoring = {
    'accuracy': make_scorer(accuracy_score),
    'precision': make_scorer(precision_score, average='weighted'),
    'recall': make_scorer(recall_score, average='weighted'),
    'f1_score': make_scorer(f1_score, average='macro'),
    'roc_auc': make_scorer(roc_auc_score, needs_proba=True, average='weighted')
}

# performing nested cross-validation
clf = GridSearchCV(estimator=rfc, param_grid=param_grid, cv=inner_cv)
cv_dic = cross_validate(clf, X, Y, cv=outer_cv, scoring=scoring, return_estimator=True, return_train_score=False)
mean_acc_score = cv_dic['test_accuracy'].mean()
mean_prec_score = cv_dic['test_precision'].mean()
mean_rec_score = cv_dic['test_recall'].mean()
mean_f1_score = cv_dic['test_f1_score'].mean()
mean_roc_auc = cv_dic['test_roc_auc'].mean()  # Mean ROC AUC score


print('nested_accuracy_scores:   ', cv_dic['test_accuracy'])
print('mean score:            {0:.4f}'.format(mean_acc_score))

print('nested_precision_scores:   ', cv_dic['test_precision'])
print('mean score:            {0:.4f}'.format(mean_prec_score))

print('nested_recall_scores:   ', cv_dic['test_recall'])
print('mean score:            {0:.4f}'.format(mean_rec_score))

print('nested_f1_scores:   ', cv_dic['test_f1_score'])
print('mean score:            {0:.4f}'.format(mean_f1_score))

print('nested_roc_auc_scores:   ', cv_dic['test_roc_auc'])
print('mean score:            {0:.4f}'.format(mean_roc_auc))
# Out:
# nested_accuracy_scores:    [0.96969697 0.89393939 0.84848485 0.83333333 0.98484848 0.89393939
#  0.98484848 0.83333333 0.92424242 0.89393939 0.90909091 0.74242424
#  0.75757576 0.78787879 0.92424242 0.87878788 1.         0.8030303
#  0.95454545 0.87878788 0.81818182 0.95454545 0.77272727 0.89393939
#  0.87878788 0.98484848 0.93939394 0.98484848 0.71212121 0.74242424
#  0.92424242 0.95454545 0.84848485 0.95454545 0.8030303  0.86363636
#  0.92424242 0.89393939 0.96969697 0.93939394 0.8030303  0.8030303
#  0.68181818 0.87878788]
# mean score:            0.8778
# nested_precision_scores:    [0.96969697 0.89466089 0.85885167 0.88571429 0.98520085 0.89337255
#  0.98545455 0.87052342 0.92981093 0.91788856 0.91831852 0.82724683
#  0.85454545 0.79265734 0.92398198 0.89747475 1.         0.80154426
#  0.95959596 0.8885851  0.87878788 0.95538803 0.86013986 0.89525499
#  0.90909091 0.98520085 0.94213287 0.98545455 0.79435379 0.73623129
#  0.93730408 0.95959596 0.8790107  0.95959596 0.85479682 0.90082645
#  0.92398198 0.89525499 0.97202797 0.94213287 0.82815249 0.85479682
#  0.80319882 0.8885851 ]
# mean score:            0.8999
# nested_recall_scores:    [0.96969697 0.89393939 0.84848485 0.83333333 0.98484848 0.89393939
#  0.98484848 0.83333333 0.92424242 0.89393939 0.90909091 0.74242424
#  0.75757576 0.78787879 0.92424242 0.87878788 1.         0.8030303
#  0.95454545 0.87878788 0.81818182 0.95454545 0.77272727 0.89393939
#  0.87878788 0.98484848 0.93939394 0.98484848 0.71212121 0.74242424
#  0.92424242 0.95454545 0.84848485 0.95454545 0.8030303  0.86363636
#  0.92424242 0.89393939 0.96969697 0.93939394 0.8030303  0.8030303
#  0.68181818 0.87878788]
# mean score:            0.8778
# nested_f1_scores:    [0.9672619  0.88199234 0.84134615 0.8314372  0.98347935 0.88435544
#  0.98377182 0.83017544 0.92011619 0.89090909 0.90480769 0.74189096
#  0.75735294 0.77463415 0.91739675 0.87464387 1.         0.78523154
#  0.95206972 0.87307692 0.81666667 0.95131547 0.77225673 0.88640275
#  0.87593985 0.98347935 0.93560976 0.98377182 0.71152519 0.70681996
#  0.92118462 0.95206972 0.84492481 0.95206972 0.80078941 0.86105263
#  0.91739675 0.88640275 0.96780488 0.93560976 0.7974026  0.80078941
#  0.68174512 0.87307692]
# mean score:            0.8730
# nested_roc_auc_scores:    [0.99603175 0.98710317 0.92361111 0.98313492 1.         0.98214286
#  1.         0.92559524 0.99206349 0.99107143 0.98412698 0.8139881
#  0.87003968 0.92559524 0.97321429 0.96031746 1.         0.89980159
#  0.98115079 0.97718254 0.94940476 0.99404762 0.94097222 0.94642857
#  0.93849206 0.99305556 0.97619048 1.         0.7514881  0.89285714
#  0.98511905 1.         0.91517857 1.         0.91517857 1.
#  0.98710317 0.95138889 1.         0.98115079 0.91517857 0.94097222
#  0.89236111 0.98313492]
# mean score:            0.9549

# %%
sensitivity_scores = []
specificity_scores = []

# iteration over the outer folds to calculate average sensitivity and specificity
for i, (train_index, test_index) in enumerate(logo.split(X, Y, groups)):
    print(f"Fold {i + 1}:")

    # getting the trained estimator for the present fold
    estimator = cv_dic['estimator'][i]
    
    # predicting on the test set
    y_pred = estimator.predict(X[test_index])
    
    # creating confusion matrix
    tn, fp, fn, tp = confusion_matrix(Y[test_index], y_pred).ravel()
    
    # calculating the sensitivity and specificity
    sensitivity = tp / (tp + fn)
    specificity = tn / (tn + fp)
    
    print(f"Sensitivity: {sensitivity:.4f}")
    print(f"Specificity: {specificity:.4f}")
    print("=" * 30)
    
    # store the sensitivity and specificity scores
    sensitivity_scores.append(sensitivity)
    specificity_scores.append(specificity)

    
    # calculate and print the averages of the sensitivity and specificity scores previously calculated
average_sensitivity = np.mean(sensitivity_scores)
average_specificity = np.mean(specificity_scores)

print("Average Sensitivity:", average_sensitivity)
print("Average Specificity:", average_specificity)
# Out:
# Fold 1:
# Sensitivity: 0.9583
# Specificity: 0.9762
# ==============================
# Fold 2:
# Sensitivity: 0.7917
# Specificity: 0.9524
# ==============================
# Fold 3:
# Sensitivity: 0.8750
# Specificity: 0.8333
# ==============================
# Fold 4:
# Sensitivity: 1.0000
# Specificity: 0.7381
# ==============================
# Fold 5:
# Sensitivity: 0.9583
# Specificity: 1.0000
# ==============================
# Fold 6:
# Sensitivity: 0.8333
# Specificity: 0.9286
# ==============================
# Fold 7:
# Sensitivity: 1.0000
# Specificity: 0.9762
# ==============================
# Fold 8:
# Sensitivity: 0.9583
# Specificity: 0.7619
# ==============================
# Fold 9:
# Sensitivity: 0.9583
# Specificity: 0.9048
# ==============================
# Fold 10:
# Sensitivity: 1.0000
# Specificity: 0.8333
# ==============================
# Fold 11:
# Sensitivity: 0.9583
# Specificity: 0.8810
# ==============================
# Fold 12:
# Sensitivity: 0.9583
# Specificity: 0.6190
# ==============================
# Fold 13:
# Sensitivity: 1.0000
# Specificity: 0.6190
# ==============================
# Fold 14:
# Sensitivity: 0.7500
# Specificity: 0.8095
# ==============================
# Fold 15:
# Sensitivity: 0.8750
# Specificity: 0.9524
# ==============================
# Fold 16:
# Sensitivity: 0.9583
# Specificity: 0.8333
# ==============================
# Fold 17:
# Sensitivity: 1.0000
# Specificity: 1.0000
# ==============================
# Fold 18:
# Sensitivity: 0.7083
# Specificity: 0.8571
# ==============================
# Fold 19:
# Sensitivity: 1.0000
# Specificity: 0.9286
# ==============================
# Fold 20:
# Sensitivity: 0.9167
# Specificity: 0.8571
# ==============================
# Fold 21:
# Sensitivity: 1.0000
# Specificity: 0.7143
# ==============================
# Fold 22:
# Sensitivity: 0.9583
# Specificity: 0.9524
# ==============================
# Fold 23:
# Sensitivity: 1.0000
# Specificity: 0.6429
# ==============================
# Fold 24:
# Sensitivity: 0.8750
# Specificity: 0.9048
# ==============================
# Fold 25:
# Sensitivity: 1.0000
# Specificity: 0.8095
# ==============================
# Fold 26:
# Sensitivity: 0.9583
# Specificity: 1.0000
# ==============================
# Fold 27:
# Sensitivity: 0.9583
# Specificity: 0.9286
# ==============================
# Fold 28:
# Sensitivity: 1.0000
# Specificity: 0.9762
# ==============================
# Fold 29:
# Sensitivity: 0.9167
# Specificity: 0.5952
# ==============================
# Fold 30:
# Sensitivity: 0.5417
# Specificity: 0.8571
# ==============================
# Fold 31:
# Sensitivity: 1.0000
# Specificity: 0.8810
# ==============================
# Fold 32:
# Sensitivity: 1.0000
# Specificity: 0.9286
# ==============================
# Fold 33:
# Sensitivity: 0.9583
# Specificity: 0.7857
# ==============================
# Fold 34:
# Sensitivity: 1.0000
# Specificity: 0.9286
# ==============================
# Fold 35:
# Sensitivity: 0.9583
# Specificity: 0.7143
# ==============================
# Fold 36:
# Sensitivity: 1.0000
# Specificity: 0.7857
# ==============================
# Fold 37:
# Sensitivity: 0.8750
# Specificity: 0.9524
# ==============================
# Fold 38:
# Sensitivity: 0.8750
# Specificity: 0.9048
# ==============================
# Fold 39:
# Sensitivity: 1.0000
# Specificity: 0.9524
# ==============================
# Fold 40:
# Sensitivity: 0.9583
# Specificity: 0.9286
# ==============================
# Fold 41:
# Sensitivity: 0.8750
# Specificity: 0.7619
# ==============================
# Fold 42:
# Sensitivity: 0.9583
# Specificity: 0.7143
# ==============================
# Fold 43:
# Sensitivity: 0.9583
# Specificity: 0.5238
# ==============================
# Fold 44:
# Sensitivity: 0.9167
# Specificity: 0.8571
# ==============================
# Average Sensitivity: 0.931818181818182
# Average Specificity: 0.8468614718614718

# %%
#print all performance scores that might be of interest
import scipy.stats

def calculate_stats(data):
    mean = np.mean(data)
    sd = np.std(data, ddof=1)  # using sample standard deviation (N-1)
    ci = scipy.stats.norm.interval(0.95, loc=mean, scale=sd/np.sqrt(len(data)))
    min_val = np.min(data)
    max_val = np.max(data)
    return mean, sd, ci, min_val, max_val

keys = ['test_accuracy', 'test_precision', 'test_recall', 'test_f1_score', 'test_roc_auc', 'sensitivity_scores', 'specificity_scores']

for key in keys:
    if key in cv_dic:
        data = cv_dic[key]
    elif key == 'sensitivity_scores':
        data = sensitivity_scores
    elif key == 'specificity_scores':
        data = specificity_scores

    stats = calculate_stats(data)
    print(f"{key}: Mean={stats[0]}, SD={stats[1]}, 95% CI={stats[2]}, Min={stats[3]}, Max={stats[4]}")
# Out:
# test_accuracy: Mean=0.877754820936639, SD=0.0817827897816719, 95% CI=(0.8535899948469639, 0.9019196470263142), Min=0.6818181818181818, Max=1.0
# test_precision: Mean=0.8999186563582607, SD=0.06126893341691901, 95% CI=(0.8818151760945985, 0.918022136621923), Min=0.7362312939020665, Max=1.0
# test_recall: Mean=0.877754820936639, SD=0.0817827897816719, 95% CI=(0.8535899948469639, 0.9019196470263142), Min=0.6818181818181818, Max=1.0
# test_f1_score: Mean=0.8730012752574791, SD=0.08342278266503601, 95% CI=(0.8483518711420286, 0.8976506793729295), Min=0.6817451205510907, Max=1.0
# test_roc_auc: Mean=0.9549062049062048, SD=0.05281475451014045, 95% CI=(0.9393007289727774, 0.9705116808396322), Min=0.7514880952380952, Max=1.0
# sensitivity_scores: Mean=0.931818181818182, SD=0.09211961257466697, 95% CI=(0.9045990759004482, 0.9590372877359158), Min=0.5416666666666666, Max=1.0
# specificity_scores: Mean=0.8468614718614718, SD=0.12123110855729857, 95% CI=(0.8110406266351552, 0.8826823170877883), Min=0.5238095238095238, Max=1.0

# %%
# IF this is the best-performing nested CV for the method: print best hyperparameters for each outer loop
for fold_idx, estimator in enumerate(cv_dic['estimator']):
    print(f'Fold {fold_idx + 1} - Best hyperparameters: {estimator.best_params_}')
# Out:
# Fold 1 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 150}
# Fold 2 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 150}
# Fold 3 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 100}
# Fold 4 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 100}
# Fold 5 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 25}
# Fold 6 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 25}
# Fold 7 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 50}
# Fold 8 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 150}
# Fold 9 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 50}
# Fold 10 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 25}
# Fold 11 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 50}
# Fold 12 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 50}
# Fold 13 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 50}
# Fold 14 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 50}
# Fold 15 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 50}
# Fold 16 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 100}
# Fold 17 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 100}
# Fold 18 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 50}
# Fold 19 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 100}
# Fold 20 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 50}
# Fold 21 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 50}
# Fold 22 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 50}
# Fold 23 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 100}
# Fold 24 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 150}
# Fold 25 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 150}
# Fold 26 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 100}
# Fold 27 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 25}
# Fold 28 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 25}
# Fold 29 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 25}
# Fold 30 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 25}
# Fold 31 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 100}
# Fold 32 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 50}
# Fold 33 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 50}
# Fold 34 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 25}
# Fold 35 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 150}
# Fold 36 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 25}
# Fold 37 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 150}
# Fold 38 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 100}
# Fold 39 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 25}
# Fold 40 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 25}
# Fold 41 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 25}
# Fold 42 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 50}
# Fold 43 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 150}
# Fold 44 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 25}

# %%
# IF this is the best-performing nested CV for the method: print mode of hyperparameters

from collections import defaultdict, Counter

# initialize a dictionary to contain all hyperparameters and their values across loops
hyperparameters = defaultdict(list)

# extracting hyperparameters of each outer loop
for estimator in cv_dic['estimator']:
    for param, value in estimator.best_params_.items():
        hyperparameters[param].append(value)

# count the most frequent value for each hyperparameter
for param, values in hyperparameters.items():
    most_common_value, count = Counter(values).most_common(1)[0]  # Get the most frequent value
    print(f'Hyperparameter: {param} - Most frequent value: {most_common_value} (Count: {count})')
# Out:
# Hyperparameter: max_depth - Most frequent value: 6 (Count: 44)
# Hyperparameter: max_features - Most frequent value: None (Count: 44)
# Hyperparameter: max_leaf_nodes - Most frequent value: 9 (Count: 44)
# Hyperparameter: n_estimators - Most frequent value: 50 (Count: 14)
