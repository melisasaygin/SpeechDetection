# %%
#importing the needed libraries
from sklearn.datasets import load_iris
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV, cross_validate, KFold
import numpy as np
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.model_selection import KFold
from sklearn.metrics import roc_auc_score
import numpy as np
from sklearn.model_selection import LeaveOneGroupOut
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_validate
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import f1_score
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import roc_auc_score, make_scorer, recall_score, f1_score, confusion_matrix, accuracy_score

# %%
#reading in the data we will use in the machine learning pipeline, with the top ten features of the method
df = pd.read_excel('hexoskin_2bands_training_set_10_final.xlsx')
df
# Out:
#       A_exp_dur_sd  exp_diff_mean  A_exp_diff_mean  exp_dur_sd  \
# 0         0.164364       0.127790         0.117188    0.156604
# 1         0.174588       0.201451         0.241071    0.152211
# 2         0.251690       0.199219         0.236719    0.213642
# 3         0.197705       0.285156         0.266276    0.213173
# 4         0.193377       0.159375         0.108073    0.213828
# ...            ...            ...              ...         ...
# 2899      0.209238       0.203125         0.218316    0.200555
# 2900      0.731201       1.195871         0.941894    1.135998
# 2901      0.115003       0.106337         0.101562    0.117894
# 2902      1.647685       2.145182         2.380208    1.447558
# 2903      0.163306       0.123535         0.132812    0.150457
#
#       duty_cycle_mean  A_RRV_RMSSD    RRV_RMSSD  ie_ratio_mean  \
# 0            0.492097   404.771735   376.386712       0.971761
# 1            0.486992   392.384431   351.137516       0.950939
# 2            0.476697   459.428807   457.608476       0.913378
# 3            0.477750   450.569753   439.827676       0.918119
# 4            0.481671   516.192869   457.645154       0.936229
# ...               ...          ...          ...            ...
# 2899         0.490259   357.971103   334.175635       0.967894
# 2900         0.408652  1042.040237  1022.081981       0.977483
# 2901         0.496388   153.331025   185.358320       0.987026
# 2902         0.412197  3239.668637  3053.223554       0.748645
# 2903         0.480523   174.011428   159.999651       0.926293
#
#       A_duty_cycle_mean  insp_flow_sd Task_Label  Participant  Classification
# 0              0.492399      1.445912      12.0a        10785               0
# 1              0.485336      1.034691      12.0b        10785               0
# 2              0.482721      1.890795      12.0c        10785               0
# 3              0.484587      1.316481      12.0d        10785               0
# 4              0.488034      0.963488      12.0e        10785               0
# ...                 ...           ...        ...          ...             ...
# 2899           0.488741      2.209139         85        98586               0
# 2900           0.431877     12.234752         87        98586               1
# 2901           0.494804      2.990174         89        98586               0
# 2902           0.374552     14.419616         91        98586               1
# 2903           0.483312      2.040140         93        98586               0
#
# [2904 rows x 13 columns]

# %%
# extracting the features from the DataFrame
features = df.drop(columns=['Classification', 'Participant', 'Task_Label'])

# extracting the Classification (0/1) and participants from the dataframe
target = df['Classification'].values
participants = df['Participant'].values
task = df['Task_Label'].values

# extracting the feature names
feature_names = features.columns.tolist()

# converting the features, target, participants to numpy arrays
features_array = features.values
target_array = target

# creating the dictionary with the needed format to enter into the nested cross-validation
data_dict = {
    'data': features_array,
    'target': target_array,
    'feature_names': feature_names,
    'participants': participants,
    'task': task
}

data_dict
# Out:
# {'data': array([[ 0.1643645,  0.1277902,  0.1171875, ...,  0.971761 ,  0.4923987,
#           1.4459118],
#         [ 0.1745884,  0.2014509,  0.2410714, ...,  0.9509391,  0.4853361,
#           1.0346914],
#         [ 0.2516897,  0.1992188,  0.2367188, ...,  0.9133779,  0.4827207,
#           1.8907954],
#         ...,
#         [ 0.1150031,  0.1063368,  0.1015625, ...,  0.9870256,  0.4948042,
#           2.9901739],
#         [ 1.6476847,  2.1451823,  2.3802083, ...,  0.7486445,  0.3745517,
#          14.419616 ],
#         [ 0.1633064,  0.1235352,  0.1328125, ...,  0.926293 ,  0.4833117,
#           2.0401398]]),
#  'target': array([0, 0, 0, ..., 0, 1, 0]),
#  'feature_names': ['A_exp_dur_sd',
#   'exp_diff_mean',
#   'A_exp_diff_mean',
#   'exp_dur_sd',
#   'duty_cycle_mean',
#   'A_RRV_RMSSD',
#   'RRV_RMSSD',
#   'ie_ratio_mean',
#   'A_duty_cycle_mean',
#   'insp_flow_sd'],
#  'participants': array([10785, 10785, 10785, ..., 98586, 98586, 98586]),
#  'task': array(['12.0a', '12.0b', '12.0c', ..., 89, 91, 93], dtype=object)}

# %%
#running the nested cross-validation for the 2bandsRIP method using Random Forest
from sklearn.metrics import accuracy_score, precision_score, recall_score
import xgboost as xgb

# random seed for reproducibility
random_seed = 1
np.random.seed(random_seed)

X = data_dict['data']
Y = data_dict['target']
groups = data_dict['participants']

# setting up the parameter grid: the combinations of these will be tried out for ever outer loop's inner loop
param_grid = {
    'n_estimators': [25, 50, 100, 150],
    'max_features': ['sqrt', 'log2', None],
    'max_depth': [3, 6, 9],
    'max_leaf_nodes': [3, 6, 9],
}

rfc = RandomForestClassifier(random_state=random_seed, class_weight="balanced")

logo = LeaveOneGroupOut()


# defining the techniques to use for the inner and outer loops
inner_cv = KFold(n_splits=5, shuffle=True, random_state=1)
outer_cv = logo.split(X, Y, groups)

scoring = {
    'accuracy': make_scorer(accuracy_score),
    'precision': make_scorer(precision_score, average='weighted'),
    'recall': make_scorer(recall_score, average='weighted'),
    'f1_score': make_scorer(f1_score, average='macro'),
    'roc_auc': make_scorer(roc_auc_score, needs_proba=True, average='weighted')
}

# performing nested cross-validation
clf = GridSearchCV(estimator=rfc, param_grid=param_grid, cv=inner_cv)
cv_dic = cross_validate(clf, X, Y, cv=outer_cv, scoring=scoring, return_estimator=True, return_train_score=False)
mean_acc_score = cv_dic['test_accuracy'].mean()
mean_prec_score = cv_dic['test_precision'].mean()
mean_rec_score = cv_dic['test_recall'].mean()
mean_f1_score = cv_dic['test_f1_score'].mean()
mean_roc_auc = cv_dic['test_roc_auc'].mean()  # Mean ROC AUC score


print('nested_accuracy_scores:   ', cv_dic['test_accuracy'])
print('mean score:            {0:.4f}'.format(mean_acc_score))

print('nested_precision_scores:   ', cv_dic['test_precision'])
print('mean score:            {0:.4f}'.format(mean_prec_score))

print('nested_recall_scores:   ', cv_dic['test_recall'])
print('mean score:            {0:.4f}'.format(mean_rec_score))

print('nested_f1_scores:   ', cv_dic['test_f1_score'])
print('mean score:            {0:.4f}'.format(mean_f1_score))

print('nested_roc_auc_scores:   ', cv_dic['test_roc_auc'])
print('mean score:            {0:.4f}'.format(mean_roc_auc))
# Out:
# nested_accuracy_scores:    [0.96969697 0.89393939 0.92424242 0.83333333 0.98484848 0.96969697
#  0.98484848 0.83333333 0.89393939 0.90909091 0.89393939 0.71212121
#  0.68181818 0.86363636 0.84848485 0.92424242 1.         0.75757576
#  0.92424242 0.87878788 0.87878788 0.93939394 0.74242424 0.92424242
#  0.84848485 0.96969697 0.90909091 0.98484848 0.77272727 0.78787879
#  0.84848485 0.92424242 0.84848485 0.95454545 0.83333333 0.78787879
#  0.92424242 0.87878788 0.96969697 0.95454545 0.81818182 0.77272727
#  0.68181818 0.87878788]
# mean score:            0.8753
# nested_precision_scores:    [0.97107438 0.89962333 0.92611833 0.87052342 0.98520085 0.97107438
#  0.98545455 0.87052342 0.9000259  0.91223776 0.91788856 0.76204441
#  0.7805765  0.87024087 0.84710744 0.92981093 1.         0.75256917
#  0.92532151 0.8885851  0.90909091 0.94008264 0.84922395 0.92398198
#  0.89304813 0.97107438 0.91831852 0.98545455 0.84046429 0.78787879
#  0.8790107  0.93730408 0.89304813 0.95959596 0.87052342 0.86602871
#  0.92611833 0.87809917 0.97202797 0.95538803 0.82911825 0.82387935
#  0.83030303 0.8885851 ]
# mean score:            0.8976
# nested_recall_scores:    [0.96969697 0.89393939 0.92424242 0.83333333 0.98484848 0.96969697
#  0.98484848 0.83333333 0.89393939 0.90909091 0.89393939 0.71212121
#  0.68181818 0.86363636 0.84848485 0.92424242 1.         0.75757576
#  0.92424242 0.87878788 0.87878788 0.93939394 0.74242424 0.92424242
#  0.84848485 0.96969697 0.90909091 0.98484848 0.77272727 0.78787879
#  0.84848485 0.92424242 0.84848485 0.95454545 0.83333333 0.78787879
#  0.92424242 0.87878788 0.96969697 0.95454545 0.81818182 0.77272727
#  0.68181818 0.87878788]
# mean score:            0.8753
# nested_f1_scores:    [0.96663296 0.87927881 0.91570881 0.83017544 0.98347935 0.96663296
#  0.98377182 0.83017544 0.88816267 0.90341463 0.89090909 0.70884606
#  0.68174512 0.85620915 0.83316481 0.92011619 1.         0.72727273
#  0.91885911 0.87307692 0.87593985 0.93326593 0.7423651  0.91739675
#  0.84622554 0.96663296 0.90480769 0.98377182 0.77141538 0.77083333
#  0.84492481 0.92118462 0.84622554 0.95206972 0.83017544 0.78709677
#  0.91570881 0.86653185 0.96780488 0.95131547 0.80961538 0.77014163
#  0.68115942 0.87307692]
# mean score:            0.8702
# nested_roc_auc_scores:    [0.99603175 0.99007937 0.9702381  0.95634921 0.99801587 1.
#  1.         0.9484127  0.9781746  0.98412698 0.97420635 0.77083333
#  0.81547619 0.92261905 0.92063492 0.96428571 1.         0.90972222
#  0.9702381  0.96329365 0.96974206 0.99206349 0.91269841 0.96031746
#  0.92906746 0.99603175 0.98412698 1.         0.85119048 0.87896825
#  0.96924603 1.         0.94047619 0.99702381 0.9375     0.98710317
#  0.99503968 0.94047619 0.99206349 0.96775794 0.90575397 0.92757937
#  0.89732143 0.97519841]
# mean score:            0.9532

# %%
sensitivity_scores = []
specificity_scores = []

# iteration over the outer folds to calculate average sensitivity and specificity
for i, (train_index, test_index) in enumerate(logo.split(X, Y, groups)):
    print(f"Fold {i + 1}:")

    # getting the trained estimator for the present fold
    estimator = cv_dic['estimator'][i]
    
    # predicting on the test set
    y_pred = estimator.predict(X[test_index])
    
    # creating confusion matrix
    tn, fp, fn, tp = confusion_matrix(Y[test_index], y_pred).ravel()
    
    # calculating the sensitivity and specificity
    sensitivity = tp / (tp + fn)
    specificity = tn / (tn + fp)
    
    print(f"Sensitivity: {sensitivity:.4f}")
    print(f"Specificity: {specificity:.4f}")
    print("=" * 30)
    
    # store the sensitivity and specificity scores
    sensitivity_scores.append(sensitivity)
    specificity_scores.append(specificity)

    
    # calculate and print the averages of the sensitivity and specificity scores previously calculated
average_sensitivity = np.mean(sensitivity_scores)
average_specificity = np.mean(specificity_scores)

print("Average Sensitivity:", average_sensitivity)
print("Average Specificity:", average_specificity)
# Out:
# Fold 1:
# Sensitivity: 0.9167
# Specificity: 1.0000
# ==============================
# Fold 2:
# Sensitivity: 0.7500
# Specificity: 0.9762
# ==============================
# Fold 3:
# Sensitivity: 0.8333
# Specificity: 0.9762
# ==============================
# Fold 4:
# Sensitivity: 0.9583
# Specificity: 0.7619
# ==============================
# Fold 5:
# Sensitivity: 0.9583
# Specificity: 1.0000
# ==============================
# Fold 6:
# Sensitivity: 0.9167
# Specificity: 1.0000
# ==============================
# Fold 7:
# Sensitivity: 1.0000
# Specificity: 0.9762
# ==============================
# Fold 8:
# Sensitivity: 0.9583
# Specificity: 0.7619
# ==============================
# Fold 9:
# Sensitivity: 0.9167
# Specificity: 0.8810
# ==============================
# Fold 10:
# Sensitivity: 0.9167
# Specificity: 0.9048
# ==============================
# Fold 11:
# Sensitivity: 1.0000
# Specificity: 0.8333
# ==============================
# Fold 12:
# Sensitivity: 0.8333
# Specificity: 0.6429
# ==============================
# Fold 13:
# Sensitivity: 0.9167
# Specificity: 0.5476
# ==============================
# Fold 14:
# Sensitivity: 0.8750
# Specificity: 0.8571
# ==============================
# Fold 15:
# Sensitivity: 0.7500
# Specificity: 0.9048
# ==============================
# Fold 16:
# Sensitivity: 0.9583
# Specificity: 0.9048
# ==============================
# Fold 17:
# Sensitivity: 1.0000
# Specificity: 1.0000
# ==============================
# Fold 18:
# Sensitivity: 0.5833
# Specificity: 0.8571
# ==============================
# Fold 19:
# Sensitivity: 0.9167
# Specificity: 0.9286
# ==============================
# Fold 20:
# Sensitivity: 0.9167
# Specificity: 0.8571
# ==============================
# Fold 21:
# Sensitivity: 1.0000
# Specificity: 0.8095
# ==============================
# Fold 22:
# Sensitivity: 0.8750
# Specificity: 0.9762
# ==============================
# Fold 23:
# Sensitivity: 1.0000
# Specificity: 0.5952
# ==============================
# Fold 24:
# Sensitivity: 0.8750
# Specificity: 0.9524
# ==============================
# Fold 25:
# Sensitivity: 1.0000
# Specificity: 0.7619
# ==============================
# Fold 26:
# Sensitivity: 0.9167
# Specificity: 1.0000
# ==============================
# Fold 27:
# Sensitivity: 0.9583
# Specificity: 0.8810
# ==============================
# Fold 28:
# Sensitivity: 1.0000
# Specificity: 0.9762
# ==============================
# Fold 29:
# Sensitivity: 0.9583
# Specificity: 0.6667
# ==============================
# Fold 30:
# Sensitivity: 0.7083
# Specificity: 0.8333
# ==============================
# Fold 31:
# Sensitivity: 0.9583
# Specificity: 0.7857
# ==============================
# Fold 32:
# Sensitivity: 1.0000
# Specificity: 0.8810
# ==============================
# Fold 33:
# Sensitivity: 1.0000
# Specificity: 0.7619
# ==============================
# Fold 34:
# Sensitivity: 1.0000
# Specificity: 0.9286
# ==============================
# Fold 35:
# Sensitivity: 0.9583
# Specificity: 0.7619
# ==============================
# Fold 36:
# Sensitivity: 1.0000
# Specificity: 0.6667
# ==============================
# Fold 37:
# Sensitivity: 0.8333
# Specificity: 0.9762
# ==============================
# Fold 38:
# Sensitivity: 0.7917
# Specificity: 0.9286
# ==============================
# Fold 39:
# Sensitivity: 1.0000
# Specificity: 0.9524
# ==============================
# Fold 40:
# Sensitivity: 0.9583
# Specificity: 0.9524
# ==============================
# Fold 41:
# Sensitivity: 0.8333
# Specificity: 0.8095
# ==============================
# Fold 42:
# Sensitivity: 0.9167
# Specificity: 0.6905
# ==============================
# Fold 43:
# Sensitivity: 1.0000
# Specificity: 0.5000
# ==============================
# Fold 44:
# Sensitivity: 0.9167
# Specificity: 0.8571
# ==============================
# Average Sensitivity: 0.9166666666666667
# Average Specificity: 0.8517316017316017

# %%
#print all performance scores that might be of interest
import scipy.stats

def calculate_stats(data):
    mean = np.mean(data)
    sd = np.std(data, ddof=1)  # using sample standard deviation (N-1)
    ci = scipy.stats.norm.interval(0.95, loc=mean, scale=sd/np.sqrt(len(data)))
    min_val = np.min(data)
    max_val = np.max(data)
    return mean, sd, ci, min_val, max_val

keys = ['test_accuracy', 'test_precision', 'test_recall', 'test_f1_score', 'test_roc_auc', 'sensitivity_scores', 'specificity_scores']

for key in keys:
    if key in cv_dic:
        data = cv_dic[key]
    elif key == 'sensitivity_scores':
        data = sensitivity_scores
    elif key == 'specificity_scores':
        data = specificity_scores

    stats = calculate_stats(data)
    print(f"{key}: Mean={stats[0]}, SD={stats[1]}, 95% CI={stats[2]}, Min={stats[3]}, Max={stats[4]}")
# Out:
# test_accuracy: Mean=0.8753443526170798, SD=0.08387539992498674, 95% CI=(0.8505612111052762, 0.9001274941288834), Min=0.6818181818181818, Max=1.0
# test_precision: Mean=0.8975829348123514, SD=0.06176587939484153, 95% CI=(0.8793326190938885, 0.9158332505308143), Min=0.7525691699604743, Max=1.0
# test_recall: Mean=0.8753443526170798, SD=0.08387539992498674, 95% CI=(0.8505612111052762, 0.9001274941288834), Min=0.6818181818181818, Max=1.0
# test_f1_score: Mean=0.870166311318276, SD=0.08485645873256416, 95% CI=(0.8450932907801866, 0.8952393318563655), Min=0.6811594202898551, Max=1.0
# test_roc_auc: Mean=0.9531700937950938, SD=0.050984405214460404, 95% CI=(0.9381054415793647, 0.9682347460108228), Min=0.7708333333333334, Max=1.0
# sensitivity_scores: Mean=0.9166666666666667, SD=0.09207975983104341, 95% CI=(0.8894593362657799, 0.9438739970675536), Min=0.5833333333333334, Max=1.0
# specificity_scores: Mean=0.8517316017316017, SD=0.13039634658433782, 95% CI=(0.813202651492175, 0.8902605519710284), Min=0.5, Max=1.0

# %%
# IF this is the best-performing nested CV for the method: print best hyperparameters for each outer loop
for fold_idx, estimator in enumerate(cv_dic['estimator']):
    print(f'Fold {fold_idx + 1} - Best hyperparameters: {estimator.best_params_}')
# Out:
# Fold 1 - Best hyperparameters: {'max_depth': 9, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 50}
# Fold 2 - Best hyperparameters: {'max_depth': 9, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 100}
# Fold 3 - Best hyperparameters: {'max_depth': 6, 'max_features': 'sqrt', 'max_leaf_nodes': 9, 'n_estimators': 150}
# Fold 4 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 50}
# Fold 5 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 150}
# Fold 6 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 50}
# Fold 7 - Best hyperparameters: {'max_depth': 9, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 100}
# Fold 8 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 50}
# Fold 9 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 25}
# Fold 10 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 150}
# Fold 11 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 100}
# Fold 12 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 100}
# Fold 13 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 100}
# Fold 14 - Best hyperparameters: {'max_depth': 9, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 100}
# Fold 15 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 25}
# Fold 16 - Best hyperparameters: {'max_depth': 9, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 100}
# Fold 17 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 150}
# Fold 18 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 50}
# Fold 19 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 150}
# Fold 20 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 150}
# Fold 21 - Best hyperparameters: {'max_depth': 9, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 100}
# Fold 22 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 150}
# Fold 23 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 150}
# Fold 24 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 150}
# Fold 25 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 150}
# Fold 26 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 150}
# Fold 27 - Best hyperparameters: {'max_depth': 9, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 100}
# Fold 28 - Best hyperparameters: {'max_depth': 9, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 100}
# Fold 29 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 150}
# Fold 30 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 150}
# Fold 31 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 150}
# Fold 32 - Best hyperparameters: {'max_depth': 6, 'max_features': 'sqrt', 'max_leaf_nodes': 9, 'n_estimators': 100}
# Fold 33 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 100}
# Fold 34 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 100}
# Fold 35 - Best hyperparameters: {'max_depth': 9, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 150}
# Fold 36 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 25}
# Fold 37 - Best hyperparameters: {'max_depth': 9, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 100}
# Fold 38 - Best hyperparameters: {'max_depth': 9, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 50}
# Fold 39 - Best hyperparameters: {'max_depth': 9, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 25}
# Fold 40 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 25}
# Fold 41 - Best hyperparameters: {'max_depth': 6, 'max_features': 'sqrt', 'max_leaf_nodes': 9, 'n_estimators': 25}
# Fold 42 - Best hyperparameters: {'max_depth': 6, 'max_features': 'sqrt', 'max_leaf_nodes': 9, 'n_estimators': 150}
# Fold 43 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 100}
# Fold 44 - Best hyperparameters: {'max_depth': 6, 'max_features': None, 'max_leaf_nodes': 9, 'n_estimators': 25}

# %%
# IF this is the best-performing nested CV for the method: print mode of hyperparameters

from collections import defaultdict, Counter

# initialize a dictionary to contain all hyperparameters and their values across loops
hyperparameters = defaultdict(list)

# extracting hyperparameters of each outer loop
for estimator in cv_dic['estimator']:
    for param, value in estimator.best_params_.items():
        hyperparameters[param].append(value)

# count the most frequent value for each hyperparameter
for param, values in hyperparameters.items():
    most_common_value, count = Counter(values).most_common(1)[0]  # Get the most frequent value
    print(f'Hyperparameter: {param} - Most frequent value: {most_common_value} (Count: {count})')
# Out:
# Hyperparameter: max_depth - Most frequent value: 6 (Count: 32)
# Hyperparameter: max_features - Most frequent value: None (Count: 40)
# Hyperparameter: max_leaf_nodes - Most frequent value: 9 (Count: 44)
# Hyperparameter: n_estimators - Most frequent value: 150 (Count: 16)
